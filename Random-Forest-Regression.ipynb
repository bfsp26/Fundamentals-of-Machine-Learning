# %% [markdown]
# # **Random Forest Regression**

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/jeffprosise/Machine-Learning/master/Data/pacific-heights.csv'
df = pd.read_csv(url)
df.head()
# Out:
#                       address  bathrooms  bedrooms  finishedsqft lastsolddate  \
# 0            2243 Franklin St        2.0         2          1463     2/5/2016
# 1      2002 Pacific Ave APT 4        3.5         3          3291    1/22/2016
# 2  1945 Washington St APT 411        1.0         1           653   12/16/2015
# 3    1896 Pacific Ave APT 802        2.5         2          2272   12/17/2014
# 4  1840 Washington St APT 603        1.0         1           837    12/2/2015
#
#    lastsoldprice   latitude   longitude     neighborhood  totalrooms  \
# 0        1950000  37.795139 -122.425309  Pacific Heights           7
# 1        4200000  37.794429 -122.428513  Pacific Heights           7
# 2         665000  37.792472 -122.425281  Pacific Heights           3
# 3        2735000  37.794706 -122.426347  Pacific Heights           6
# 4        1050000  37.793212 -122.423744  Pacific Heights           3
#
#        usecode  yearbuilt  zipcode
# 0  Condominium       1900    94109
# 1  Condominium       1961    94109
# 2  Condominium       1987    94109
# 3  Condominium       1924    94109
# 4  Condominium       2012    94109

# %%
df.shape
# Out:
# (439, 13)

# %%
corr_matrix = df.corr()
corr_matrix['lastsoldprice'].sort_values(ascending=False)
# Out:
# lastsoldprice    1.000000
# finishedsqft     0.840864
# bathrooms        0.768179
# totalrooms       0.670726
# bedrooms         0.606579
# zipcode          0.296032
# latitude         0.126480
# yearbuilt       -0.214365
# longitude       -0.309462
# Name: lastsoldprice, dtype: float64

# %%
df = pd.get_dummies(df, columns=['usecode'])
df.head()
# Out:
#                       address  bathrooms  bedrooms  finishedsqft lastsolddate  \
# 0            2243 Franklin St        2.0         2          1463     2/5/2016
# 1      2002 Pacific Ave APT 4        3.5         3          3291    1/22/2016
# 2  1945 Washington St APT 411        1.0         1           653   12/16/2015
# 3    1896 Pacific Ave APT 802        2.5         2          2272   12/17/2014
# 4  1840 Washington St APT 603        1.0         1           837    12/2/2015
#
#    lastsoldprice   latitude   longitude     neighborhood  totalrooms  \
# 0        1950000  37.795139 -122.425309  Pacific Heights           7
# 1        4200000  37.794429 -122.428513  Pacific Heights           7
# 2         665000  37.792472 -122.425281  Pacific Heights           3
# 3        2735000  37.794706 -122.426347  Pacific Heights           6
# 4        1050000  37.793212 -122.423744  Pacific Heights           3
#
#    yearbuilt  zipcode  usecode_Condominium  usecode_Cooperative  \
# 0       1900    94109                    1                    0
# 1       1961    94109                    1                    0
# 2       1987    94109                    1                    0
# 3       1924    94109                    1                    0
# 4       2012    94109                    1                    0
#
#    usecode_Duplex  usecode_MultiFamily2To4  usecode_SingleFamily  \
# 0               0                        0                     0
# 1               0                        0                     0
# 2               0                        0                     0
# 3               0                        0                     0
# 4               0                        0                     0
#
#    usecode_Townhouse
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
corr_matrix = df.corr()
corr_matrix['lastsoldprice'].sort_values(ascending=False)
# Out:
# lastsoldprice              1.000000
# finishedsqft               0.840864
# bathrooms                  0.768179
# totalrooms                 0.670726
# usecode_SingleFamily       0.638482
# bedrooms                   0.606579
# zipcode                    0.296032
# latitude                   0.126480
# usecode_Duplex             0.006292
# usecode_MultiFamily2To4   -0.019009
# usecode_Townhouse         -0.025467
# usecode_Cooperative       -0.025556
# yearbuilt                 -0.214365
# longitude                 -0.309462
# usecode_Condominium       -0.598575
# Name: lastsoldprice, dtype: float64

# %%
df = df[['bathrooms', 'bedrooms', 'finishedsqft', 'totalrooms', 'usecode_Condominium', 'usecode_SingleFamily', 'lastsoldprice']]
df.head()
# Out:
#    bathrooms  bedrooms  finishedsqft  totalrooms  usecode_Condominium  \
# 0        2.0         2          1463           7                    1
# 1        3.5         3          3291           7                    1
# 2        1.0         1           653           3                    1
# 3        2.5         2          2272           6                    1
# 4        1.0         1           837           3                    1
#
#    usecode_SingleFamily  lastsoldprice
# 0                     0        1950000
# 1                     0        4200000
# 2                     0         665000
# 3                     0        2735000
# 4                     0        1050000

# %%
corr_matrix = df.corr()
corr_matrix['lastsoldprice'].sort_values(ascending=False)
# Out:
# lastsoldprice           1.000000
# finishedsqft            0.840864
# bathrooms               0.768179
# totalrooms              0.670726
# usecode_SingleFamily    0.638482
# bedrooms                0.606579
# usecode_Condominium    -0.598575
# Name: lastsoldprice, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

X = df.drop('lastsoldprice', axis=1)
y = df['lastsoldprice']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

RFR = RandomForestRegressor(random_state=1234)
RFR.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=1234)

# %%
# Compute the model's R2 score
RFR.score(X_test, y_test)
# Out:
# 0.6344806574612631

# %%
# Compute the mean R2 score across five folds

from sklearn.model_selection import cross_val_score

cross_val_score(RFR, X, y, cv=5).mean()
# Out:
# 0.6630446369826232

# %%
# Use GridSearchCV for tuning hyperparameters
from sklearn.model_selection import GridSearchCV

param_grid = {
    'bootstrap' : [True, False],
    'max_depth' : [10, 50, 100],
    'max_features' : [2, 3, 4],
    'min_samples_leaf' : [3, 4, 5],
    'min_samples_split' : [5, 10, 15]
}

grid_search = GridSearchCV(estimator=RFR, param_grid=param_grid, cv=5, verbose=2)
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=5; total time=   0.2s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=2, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=5, min_samples_split=15; total time=   0.2s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=3, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=4, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=15; total time=   0.2s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=50, max_features=4, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=10; total time=   0.2s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=10; total time=   0.2s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=5; total time=   0.2s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=True, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# ...
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=2, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=5; total time=   0.2s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=10; total time=   0.2s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=3, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=3, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END bootstrap=False, max_depth=100, max_features=4, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=1234),
#              param_grid={'bootstrap': [True, False], 'max_depth': [10, 50, 100],
#                          'max_features': [2, 3, 4],
#                          'min_samples_leaf': [3, 4, 5],
#                          'min_samples_split': [5, 10, 15]},
#              verbose=2)

# %%
# Compute the mean R2 score across five folds using the best model
best_model = grid_search.best_estimator_

cross_val_score(best_model, X, y, cv=5).mean()
# Out:
# 0.7127885701180449
